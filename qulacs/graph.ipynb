# %%
with open('teach.txt','r') as f:
    data_teach = [float(line.strip()) for line in f]

with open('my_list1.txt','r') as f:
    data1 = [float(line.strip()) for line in f]

with open('my_list2.txt','r') as f:
    data2 = [float(line.strip()) for line in f]
    
with open('my_list3.txt','r') as f:
    data3 = [float(line.strip()) for line in f]
    
with open('x.txt','r') as f:
    x = [float(line.strip()) for line in f]

# %%
import matplotlib.pyplot as plt
plt.plot(x,data1,'--',label='nqubit=1')
plt.plot(x,data2,'--',label='nqubit=2')
plt.plot(x,data3,'--',label='nqubit=3')
plt.plot(x,data_teach,label='sin(πx)')

plt.legend()
